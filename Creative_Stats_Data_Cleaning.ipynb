# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'sage-dragon-413617' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=sage-dragon-413617:US:bquxjob_1ff9bd77_18e26d6e23d)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_1ff9bd77_18e26d6e23d') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT *
# FROM `bigquery-public-data.google_ads_transparency_center.creative_stats`
# LIMIT 100000

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_1ff9bd77_18e26d6e23d') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
# Warning: total number of rows (100000) exceeds max_rows (20000). Falling back to pandas display.
#                 advertiser_id             creative_id  \
# 0      AR06101118588632956929  CR17599147911524909057
# 1      AR13529253531948679169  CR10607723043843211265
# 2      AR08593965848304025601  CR01424717927134789633
# 3      AR04183151120983523329  CR12894387546611515393
# 4      AR02997330338688008193  CR09642303627942952961
# ...                       ...                     ...
# 99995  AR16138687197833330689  CR01824111368396079105
# 99996  AR16138687197833330689  CR04675465801736650753
# 99997  AR16138687197833330689  CR11824840462550695937
# 99998  AR16138687197833330689  CR03216588384789069825
# 99999  AR16138687197833330689  CR11459195190674194433
#
#                                        creative_page_url ad_format_type  \
# 0      https://adstransparency.google.com/advertiser/...          VIDEO
# 1      https://adstransparency.google.com/advertiser/...          VIDEO
# 2      https://adstransparency.google.com/advertiser/...          VIDEO
# 3      https://adstransparency.google.com/advertiser/...           TEXT
# 4      https://adstransparency.google.com/advertiser/...           TEXT
# ...                                                  ...            ...
# 99995  https://adstransparency.google.com/advertiser/...           TEXT
# 99996  https://adstransparency.google.com/advertiser/...           TEXT
# 99997  https://adstransparency.google.com/advertiser/...           TEXT
# 99998  https://adstransparency.google.com/advertiser/...           TEXT
# 99999  https://adstransparency.google.com/advertiser/...           TEXT
#
#                   advertiser_disclosed_name       advertiser_legal_name  \
# 0      Hih Invest Eskilstuna AB (Tuna Park)
# 1                    Äventyrshuset Bborg Ab
# 2                    Vakantie Discounter NL
# 3                           Last Minute doo             Last Minute doo
# 4                AD TYRES INTERNATIONAL SLU  AD TYRES INTERNATIONAL SLU
# ...                                     ...                         ...
# 99995                     Kayak Europe GmbH           Kayak Europe GmbH
# 99996                     Kayak Europe GmbH           Kayak Europe GmbH
# 99997                     Kayak Europe GmbH           Kayak Europe GmbH
# 99998                     Kayak Europe GmbH           Kayak Europe GmbH
# 99999                     Kayak Europe GmbH           Kayak Europe GmbH
#
#       advertiser_location advertiser_verification_status  \
# 0                                             UNVERIFIED
# 1                                             UNVERIFIED
# 2                                             UNVERIFIED
# 3                    "RS"                       VERIFIED
# 4                      AD                       VERIFIED
# ...                   ...                            ...
# 99995                  CH                       VERIFIED
# 99996                  CH                       VERIFIED
# 99997                  CH                       VERIFIED
# 99998                  CH                       VERIFIED
# 99999                  CH                       VERIFIED
#
#                                             region_stats  \
# 0      [{'region_code': 'EEA', 'first_shown': '2023-1...
# 1      [{'region_code': 'EEA', 'first_shown': '2024-0...
# 2      [{'region_code': 'EEA', 'first_shown': '2023-1...
# 3      [{'region_code': 'BG', 'first_shown': '2023-12...
# 4      [{'region_code': 'EEA', 'first_shown': '2023-0...
# ...                                                  ...
# 99995  [{'region_code': 'EEA', 'first_shown': '2023-0...
# 99996  [{'region_code': 'EEA', 'first_shown': '2023-0...
# 99997  [{'region_code': 'EEA', 'first_shown': '2023-0...
# 99998  [{'region_code': 'EEA', 'first_shown': '2023-0...
# 99999  [{'region_code': 'EEA', 'first_shown': '2023-0...
#
#                         audience_selection_approach_info             topic
# 0      {'demographic_info': 'CRITERIA_UNUSED', 'geo_l...        Commercial
# 1      {'demographic_info': 'CRITERIA_UNUSED', 'geo_l...        Commercial
# 2      {'demographic_info': 'CRITERIA_UNUSED', 'geo_l...        Commercial
# 3      {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
# 4      {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Autos & Vehicles
# ...                                                  ...               ...
# 99995  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
# 99996  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
# 99997  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
# 99998  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
# 99999  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...  Travel & Tourism
#
# [100000 rows x 11 columns]

# %%
import pandas as pd

# Explode 'region_stats' column to create separate rows for each dictionary
exploded_results = results.explode('region_stats')

# Normalize the exploded DataFrame to flatten the dictionaries within 'region_stats'
normalized_results = pd.json_normalize(exploded_results['region_stats'])

# Create a new DataFrame by converting the 'audience_selection_approach_info' column to a DataFrame
audience_info_df = pd.DataFrame(results['audience_selection_approach_info'].tolist())

# Concatenate the original DataFrame with the normalized DataFrame and audience_info_df
merged_results = pd.concat([exploded_results.reset_index(drop=True), normalized_results.reset_index(drop=True), audience_info_df.reset_index(drop=True)], axis=1)

# Drop the original 'region_stats' and 'audience_selection_approach_info' columns
merged_results = merged_results.drop(columns=['region_stats', 'audience_selection_approach_info'])

# Display the merged results
print("Merged Results:")
merged_results.head()
# Out:
# Merged Results:
# Warning: Total number of columns (24) exceeds max_columns (20). Falling back to pandas display.
#             advertiser_id             creative_id  \
# 0  AR06101118588632956929  CR17599147911524909057
# 1  AR06101118588632956929  CR17599147911524909057
# 2  AR13529253531948679169  CR10607723043843211265
# 3  AR13529253531948679169  CR10607723043843211265
# 4  AR08593965848304025601  CR01424717927134789633
#
#                                    creative_page_url ad_format_type  \
# 0  https://adstransparency.google.com/advertiser/...          VIDEO
# 1  https://adstransparency.google.com/advertiser/...          VIDEO
# 2  https://adstransparency.google.com/advertiser/...          VIDEO
# 3  https://adstransparency.google.com/advertiser/...          VIDEO
# 4  https://adstransparency.google.com/advertiser/...          VIDEO
#
#               advertiser_disclosed_name advertiser_legal_name  \
# 0  Hih Invest Eskilstuna AB (Tuna Park)
# 1  Hih Invest Eskilstuna AB (Tuna Park)
# 2                Äventyrshuset Bborg Ab
# 3                Äventyrshuset Bborg Ab
# 4                Vakantie Discounter NL
#
#   advertiser_location advertiser_verification_status       topic region_code  \
# 0                                         UNVERIFIED  Commercial         EEA
# 1                                         UNVERIFIED  Commercial          SE
# 2                                         UNVERIFIED  Commercial         EEA
# 3                                         UNVERIFIED  Commercial          SE
# 4                                         UNVERIFIED  Commercial         EEA
#
#    ... times_shown_upper_bound times_shown_start_date  \
# 0  ...                 20000.0             2023-10-22
# 1  ...                 20000.0             2023-10-22
# 2  ...                     NaN                   None
# 3  ...                     NaN                   None
# 4  ...                     NaN                   None
#
#   times_shown_availability_date  \
# 0                          None
# 1                          None
# 2                    2024-05-04
# 3                    2024-05-04
# 4                    2024-03-30
#
#          surface_serving_stats.surface_serving_stats  surface_serving_stats  \
# 0  [{'surface': 'MAPS', 'times_shown_upper_bound'...                    NaN
# 1  [{'surface': 'SEARCH', 'times_shown_upper_boun...                    NaN
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
#
#     demographic_info                    geo_location  \
# 0    CRITERIA_UNUSED                 CRITERIA_UNUSED
# 1    CRITERIA_UNUSED                 CRITERIA_UNUSED
# 2    CRITERIA_UNUSED                 CRITERIA_UNUSED
# 3  CRITERIA_INCLUDED               CRITERIA_INCLUDED
# 4  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED
#
#                contextual_signals   customer_lists topics_of_interest
# 0               CRITERIA_INCLUDED  CRITERIA_UNUSED    CRITERIA_UNUSED
# 1               CRITERIA_INCLUDED  CRITERIA_UNUSED    CRITERIA_UNUSED
# 2  CRITERIA_INCLUDED_AND_EXCLUDED  CRITERIA_UNUSED    CRITERIA_UNUSED
# 3               CRITERIA_INCLUDED  CRITERIA_UNUSED    CRITERIA_UNUSED
# 4  CRITERIA_INCLUDED_AND_EXCLUDED  CRITERIA_UNUSED    CRITERIA_UNUSED
#
# [5 rows x 24 columns]

# %%
from google.colab import files

# Save the merged dataframe as an Excel file
merged_results.to_excel('creative_stats.xlsx', index=False)

# Download the Excel file
files.download('creative_stats.xlsx')
