# %%
# @title Setup
from google.colab import auth
from google.cloud import bigquery
from google.colab import data_table

project = 'sage-dragon-413617' # Project ID inserted based on the query results selected to explore
location = 'US' # Location inserted based on the query results selected to explore
client = bigquery.Client(project=project, location=location)
data_table.enable_dataframe_formatter()
auth.authenticate_user()

# %% [markdown]
# ## Reference SQL syntax from the original job
# Use the ```jobs.query```
# [method](https://cloud.google.com/bigquery/docs/reference/rest/v2/jobs/query) to
# return the SQL syntax from the job. This can be copied from the output cell
# below to edit the query now or in the future. Alternatively, you can use
# [this link](https://console.cloud.google.com/bigquery?j=sage-dragon-413617:US:bquxjob_4011429c_18e26db4a42)
# back to BigQuery to edit the query within the BigQuery user interface.

# %%
# Running this code will display the query used to generate your previous job

job = client.get_job('bquxjob_4011429c_18e26db4a42') # Job ID inserted based on the query results selected to explore
print(job.query)
# Out:
# SELECT *
# FROM `bigquery-public-data.google_ads_transparency_center.removed_creative_stats`
# LIMIT 100000

# %% [markdown]
# # Result set loaded from BigQuery job as a DataFrame
# Query results are referenced from the Job ID ran from BigQuery and the query
# does not need to be re-run to explore results. The ```to_dataframe```
# [method](https://googleapis.dev/python/bigquery/latest/generated/google.cloud.bigquery.job.QueryJob.html#google.cloud.bigquery.job.QueryJob.to_dataframe)
# downloads the results to a Pandas DataFrame by using the BigQuery Storage API.
#
# To edit query syntax, you can do so from the BigQuery SQL editor or in the
# ```Optional:``` sections below.

# %%
# Running this code will read results from your previous job

job = client.get_job('bquxjob_4011429c_18e26db4a42') # Job ID inserted based on the query results selected to explore
results = job.to_dataframe()
results
# Out:
# Warning: total number of rows (100000) exceeds max_rows (20000). Falling back to pandas display.
#                                        creative_page_url  \
# 0      https://adstransparency.google.com/removed/cre...
# 1      https://adstransparency.google.com/removed/cre...
# 2      https://adstransparency.google.com/removed/cre...
# 3      https://adstransparency.google.com/removed/cre...
# 4      https://adstransparency.google.com/removed/cre...
# ...                                                  ...
# 99995  https://adstransparency.google.com/removed/cre...
# 99996  https://adstransparency.google.com/removed/cre...
# 99997  https://adstransparency.google.com/removed/cre...
# 99998  https://adstransparency.google.com/removed/cre...
# 99999  https://adstransparency.google.com/removed/cre...
#
#                                             region_stats  \
# 0      [{'region_code': 'BE', 'first_shown': '2023-11...
# 1      [{'region_code': 'AT', 'first_shown': '2023-11...
# 2      [{'region_code': 'AT', 'first_shown': '2023-09...
# 3      [{'region_code': 'AT', 'first_shown': '2023-03...
# 4      [{'region_code': 'BE', 'first_shown': '2023-09...
# ...                                                  ...
# 99995  [{'region_code': 'AT', 'first_shown': '2023-11...
# 99996  [{'region_code': 'AT', 'first_shown': '2023-07...
# 99997  [{'region_code': 'AT', 'first_shown': '2023-05...
# 99998  [{'region_code': 'BG', 'first_shown': '2023-10...
# 99999  [{'region_code': 'BE', 'first_shown': '2023-09...
#
#                         audience_selection_approach_info  \
# 0      {'demographic_info': 'CRITERIA_EXCLUDED', 'geo...
# 1      {'demographic_info': 'CRITERIA_EXCLUDED', 'geo...
# 2      {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 3      {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 4      {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# ...                                                  ...
# 99995  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 99996  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 99997  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 99998  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
# 99999  {'demographic_info': 'CRITERIA_INCLUDED', 'geo...
#
#                                              disapproval
# 0      [{'removal_reason': 'Gambling and games', 'vio...
# 1      [{'removal_reason': 'Technical requirements', ...
# 2      [{'removal_reason': 'Account suspension', 'vio...
# 3      [{'removal_reason': 'Copyrights', 'violation_c...
# 4      [{'removal_reason': 'Trademarks', 'violation_c...
# ...                                                  ...
# 99995  [{'removal_reason': 'Editorial', 'violation_ca...
# 99996  [{'removal_reason': 'Editorial', 'violation_ca...
# 99997  [{'removal_reason': 'Other restricted business...
# 99998  [{'removal_reason': 'Healthcare and medicines'...
# 99999  [{'removal_reason': 'Account suspension', 'vio...
#
# [100000 rows x 4 columns]

# %%
import pandas as pd

# Explode 'region_stats' column to create separate rows for each dictionary
exploded_results = results.explode('region_stats')

# Normalize the exploded DataFrame to flatten the dictionaries within 'region_stats'
normalized_region_stats = pd.json_normalize(exploded_results['region_stats'])

# Concatenate the original DataFrame with the normalized DataFrame for 'region_stats'
merged_results_region = pd.concat([exploded_results.reset_index(drop=True), normalized_region_stats.reset_index(drop=True)], axis=1)

# Drop the 'region_stats' column
merged_results_region = merged_results_region.drop(columns=['region_stats'])

# Explode 'disapproval' column to create separate rows for each dictionary
exploded_disapproval = merged_results_region.explode('disapproval')

# Normalize the exploded DataFrame to flatten the dictionaries within 'disapproval'
normalized_disapproval = pd.json_normalize(exploded_disapproval['disapproval'])

# Concatenate the DataFrame with the normalized DataFrame for 'disapproval'
merged_results_disapproval = pd.concat([exploded_disapproval.reset_index(drop=True), normalized_disapproval.reset_index(drop=True)], axis=1)

# Drop the 'disapproval' column
merged_results_disapproval = merged_results_disapproval.drop(columns=['disapproval'])

# Convert 'audience_selection_approach_info' column to a DataFrame
audience_info_df = pd.DataFrame(merged_results_disapproval['audience_selection_approach_info'].tolist())

# Concatenate the original DataFrame with the new DataFrame containing separated columns for 'audience_selection_approach_info'
merged_results_audience = pd.concat([merged_results_disapproval.reset_index(drop=True), audience_info_df.reset_index(drop=True)], axis=1)

# Drop the 'audience_selection_approach_info' column
merged_results_final = merged_results_audience.drop(columns=['audience_selection_approach_info'])

# Displaying the final DataFrame
merged_results_final.head()
# Out:
# Warning: Total number of columns (21) exceeds max_columns (20). Falling back to pandas display.
#                                    creative_page_url region_code first_shown  \
# 0  https://adstransparency.google.com/removed/cre...          BE  2023-11-15
# 1  https://adstransparency.google.com/removed/cre...          BE  2023-11-15
# 2  https://adstransparency.google.com/removed/cre...          BG  2023-11-29
# 3  https://adstransparency.google.com/removed/cre...          BG  2023-11-29
# 4  https://adstransparency.google.com/removed/cre...          CZ  2023-11-29
#
#    last_shown times_shown_end_date  times_shown_lower_bound  \
# 0  2023-12-04           2023-12-04                      0.0
# 1  2023-12-04           2023-12-04                      0.0
# 2  2023-12-04           2023-12-04                      0.0
# 3  2023-12-04           2023-12-04                      0.0
# 4  2023-12-04           2023-12-04                      0.0
#
#    times_shown_upper_bound times_shown_start_date  \
# 0                   1000.0             2023-11-15
# 1                   1000.0             2023-11-15
# 2                   1000.0             2023-11-29
# 3                   1000.0             2023-11-29
# 4                   1000.0             2023-11-29
#
#   times_shown_availability_date  surface_serving_stats  ...  \
# 0                          None                    NaN  ...
# 1                          None                    NaN  ...
# 2                          None                    NaN  ...
# 3                          None                    NaN  ...
# 4                          None                    NaN  ...
#
#                             removal_reason               violation_category  \
# 0                       Gambling and games  RESTRICTED_CONTENT_AND_FEATURES
# 1  Requirements for third party ad serving          EDITORIAL_AND_TECHNICAL
# 2                       Gambling and games  RESTRICTED_CONTENT_AND_FEATURES
# 3  Requirements for third party ad serving          EDITORIAL_AND_TECHNICAL
# 4                       Gambling and games  RESTRICTED_CONTENT_AND_FEATURES
#
#   use_of_automated_means                                   removal_location  \
# 0                  False  [ES, PL, BE, FR, BG, DK, NL, IT, GR, PT, CZ, R...
# 1                  False                                           [GLOBAL]
# 2                  False  [ES, PL, BE, FR, BG, DK, NL, IT, GR, PT, CZ, R...
# 3                  False                                           [GLOBAL]
# 4                  False  [ES, PL, BE, FR, BG, DK, NL, IT, GR, PT, CZ, R...
#
#           decision_type   demographic_info       geo_location  \
# 0  Google investigation  CRITERIA_EXCLUDED  CRITERIA_INCLUDED
# 1  Google investigation  CRITERIA_EXCLUDED  CRITERIA_INCLUDED
# 2  Google investigation  CRITERIA_EXCLUDED  CRITERIA_INCLUDED
# 3  Google investigation  CRITERIA_EXCLUDED  CRITERIA_INCLUDED
# 4  Google investigation  CRITERIA_EXCLUDED  CRITERIA_INCLUDED
#
#   contextual_signals                  customer_lists topics_of_interest
# 0  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED    CRITERIA_UNUSED
# 1  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED    CRITERIA_UNUSED
# 2  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED    CRITERIA_UNUSED
# 3  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED    CRITERIA_UNUSED
# 4  CRITERIA_INCLUDED  CRITERIA_INCLUDED_AND_EXCLUDED    CRITERIA_UNUSED
#
# [5 rows x 21 columns]

# %%
from google.colab import files

# Save the merged dataframe as an Excel file
merged_results_final.to_excel('removed_creative_stats.xlsx', index=False)

# Download the Excel file
files.download('removed_creative_stats.xlsx')
